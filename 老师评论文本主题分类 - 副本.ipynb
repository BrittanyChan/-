# %%
# -*- coding: utf-8 -*-

import jieba

jieba.suggest_freq('魏老师', True)
jieba.suggest_freq('曹老师', True)
jieba.suggest_freq('陈老师', True)

for i in range(1,4):
    with open('./data/老师的评价'+str(i)+'.txt') as f:
        document = f.read()
    
        document_decode = document.encode('gbk').decode('gbk')
        document_cut = jieba.cut(document_decode)
        #print  ' '.join(jieba_cut)  //如果打印结果，则分词效果消失，后面的result无法显示
        result = ' '.join(document_cut)
        result = result.encode('utf-8').decode('utf-8')
        with open('./data/分词处理后的老师评价'+str(i)+'.txt', 'w') as f2:
            f2.write(result)
f.close()
f2.close()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\chenxi\AppData\Local\Temp\jieba.cache
# Loading model cost 2.219 seconds.
# Prefix dict has been built succesfully.

# %%
#从文件导入停用词表
stpwrdpath = "stop_words.txt"
stpwrd_dic = open(stpwrdpath, 'rb')
stpwrd_content = stpwrd_dic.read()
#将停用词表转换为list  
stpwrdlst = stpwrd_content.splitlines()
stpwrd_dic.close()

# %%
with open('./data/分词处理后的老师评价1.txt') as f3:
    res1 = f3.read()
    
with open('./data/分词处理后的老师评价2.txt') as f4:
    res2 = f4.read()
    
with open('./data/分词处理后的老师评价3.txt') as f5:
    res3 = f5.read()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = [res1,res2,res3]
vector = TfidfVectorizer(stop_words=stpwrdlst)
tfidf = vector.fit_transform(corpus)

# %%
wordlist = vector.get_feature_names()#获取词袋模型中的所有词  
# tf-idf矩阵 元素a[i][j]表示j词在i类文本中的tf-idf权重
weightlist = tfidf.toarray()  
#打印每类文本的tf-idf词语权重，第一个for遍历所有文本，第二个for便利某一类文本下的词语权重
for i in range(len(weightlist)):  
    print ("-------第",i,"段文本的词语tf-idf权重------")  
    for j in range(len(wordlist)):  
        print (wordlist[j],weightlist[i][j])
# Out:
# -------第 0 段文本的词语tf-idf权重------
# 一个 0.0
# 一定 0.198007665677
# 一步一个脚印 0.198007665677
# 上课 0.198007665677
# 不是 0.0
# 不用 0.198007665677
# 专心 0.198007665677
# 事情 0.0
# 作业 0.198007665677
# 保持良好 0.0
# 做好 0.0
# 充分利用 0.0
# 关注 0.0
# 兴趣 0.0
# 具体 0.0
# 分散 0.0
# 协助 0.0
# 单凭 0.0
# 即使 0.198007665677
# 只要 0.198007665677
# 可以 0.0
# 同学 0.0
# 听讲 0.198007665677
# 团结 0.0
# 头脑 0.0
# 始终如一 0.198007665677
# 孜孜以求 0.0
# 学习 0.116946517084
# 学法 0.0
# 实现 0.198007665677
# 对待 0.198007665677
# 尊敬老师 0.0
# 工作 0.0
# 希望 0.0
# 强者 0.0
# 当务之急 0.0
# 形象 0.0
# 彩虹 0.0
# 很大 0.0
# 心态 0.0
# 态度端正 0.198007665677
# 性格开朗 0.198007665677
# 成绩 0.0
# 才能 0.0
# 提高 0.0
# 提高效率 0.0
# 曹老师 0.0
# 有些 0.0
# 欲望 0.0
# 永远 0.0
# 没有 0.0
# 激发 0.0
# 热情 0.150589933485
# 理想 0.198007665677
# 目标 0.150589933485
# 稳定 0.0
# 空间 0.0
# 精力 0.0
# 经历 0.0
# 缺乏 0.0
# 美景 0.0
# 老师 0.0
# 聪明 0.0
# 能够 0.396015331355
# 能说会道 0.198007665677
# 行动 0.0
# 认真完成 0.198007665677
# 认真负责 0.0
# 记住 0.0
# 课下 0.198007665677
# 路途遥远 0.198007665677
# 踏实 0.0
# 迈进 0.0
# 铸造 0.0
# 陈老师 0.0
# 风雨 0.0
# 魏老师 0.198007665677
# -------第 1 段文本的词语tf-idf权重------
# 一个 0.164457426726
# 一定 0.0
# 一步一个脚印 0.0
# 上课 0.0
# 不是 0.164457426726
# 不用 0.0
# 专心 0.0
# 事情 0.164457426726
# 作业 0.0
# 保持良好 0.164457426726
# 做好 0.164457426726
# 充分利用 0.0
# 关注 0.0
# 兴趣 0.164457426726
# 具体 0.0
# 分散 0.0
# 协助 0.164457426726
# 单凭 0.164457426726
# 即使 0.0
# 只要 0.0
# 可以 0.164457426726
# 同学 0.164457426726
# 听讲 0.0
# 团结 0.164457426726
# 头脑 0.0
# 始终如一 0.0
# 孜孜以求 0.164457426726
# 学习 0.194262410987
# 学法 0.0
# 实现 0.0
# 对待 0.0
# 尊敬老师 0.164457426726
# 工作 0.328914853452
# 希望 0.164457426726
# 强者 0.164457426726
# 当务之急 0.164457426726
# 形象 0.164457426726
# 彩虹 0.164457426726
# 很大 0.0
# 心态 0.164457426726
# 态度端正 0.0
# 性格开朗 0.0
# 成绩 0.0
# 才能 0.164457426726
# 提高 0.0
# 提高效率 0.0
# 曹老师 0.164457426726
# 有些 0.164457426726
# 欲望 0.0
# 永远 0.164457426726
# 没有 0.0
# 激发 0.164457426726
# 热情 0.12507411199
# 理想 0.0
# 目标 0.0
# 稳定 0.0
# 空间 0.0
# 精力 0.0
# 经历 0.164457426726
# 缺乏 0.0
# 美景 0.164457426726
# 老师 0.164457426726
# 聪明 0.0
# 能够 0.0
# 能说会道 0.0
# 行动 0.0
# 认真完成 0.0
# 认真负责 0.164457426726
# 记住 0.164457426726
# 课下 0.0
# 路途遥远 0.0
# 踏实 0.0
# 迈进 0.0
# 铸造 0.164457426726
# 陈老师 0.0
# 风雨 0.164457426726
# 魏老师 0.0
# -------第 2 段文本的词语tf-idf权重------
# 一个 0.0
# 一定 0.0
# 一步一个脚印 0.0
# 上课 0.0
# 不是 0.0
# 不用 0.0
# 专心 0.0
# 事情 0.0
# 作业 0.0
# 保持良好 0.0
# 做好 0.0
# 充分利用 0.179816487546
# 关注 0.179816487546
# 兴趣 0.0
# 具体 0.179816487546
# 分散 0.179816487546
# 协助 0.0
# 单凭 0.0
# 即使 0.0
# 只要 0.0
# 可以 0.0
# 同学 0.0
# 听讲 0.0
# 团结 0.0
# 头脑 0.179816487546
# 始终如一 0.0
# 孜孜以求 0.0
# 学习 0.106202514236
# 学法 0.179816487546
# 实现 0.0
# 对待 0.0
# 尊敬老师 0.0
# 工作 0.0
# 希望 0.0
# 强者 0.0
# 当务之急 0.0
# 形象 0.0
# 彩虹 0.0
# 很大 0.179816487546
# 心态 0.0
# 态度端正 0.0
# 性格开朗 0.0
# 成绩 0.359632975093
# 才能 0.0
# 提高 0.359632975093
# 提高效率 0.179816487546
# 曹老师 0.0
# 有些 0.0
# 欲望 0.179816487546
# 永远 0.0
# 没有 0.179816487546
# 激发 0.0
# 热情 0.0
# 理想 0.0
# 目标 0.136755073631
# 稳定 0.179816487546
# 空间 0.179816487546
# 精力 0.359632975093
# 经历 0.0
# 缺乏 0.179816487546
# 美景 0.0
# 老师 0.0
# 聪明 0.179816487546
# 能够 0.0
# 能说会道 0.0
# 行动 0.179816487546
# 认真完成 0.0
# 认真负责 0.0
# 记住 0.0
# 课下 0.0
# 路途遥远 0.0
# 踏实 0.179816487546
# 迈进 0.179816487546
# 铸造 0.0
# 陈老师 0.179816487546
# 风雨 0.0
# 魏老师 0.0

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
corpus = [res1,res2,res3]
cntVector = CountVectorizer(stop_words=stpwrdlst)
cntTf = cntVector.fit_transform(corpus)

# %%
lda = LatentDirichletAllocation(n_topics=2,
                                learning_offset=50.,
                                random_state=0)
docres = lda.fit_transform(cntTf)
# Out:
# F:\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# F:\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)

# %%
print (docres)
# print (lda.components_)
# Out:
# [[ 0.97545662  0.02454338]
#  [ 0.98251508  0.01748492]
#  [ 0.02187723  0.97812277]]
# [[ 1.31397609  1.24222885  1.32799255  1.16956343  1.19815197  1.24312481
#    1.26068615  1.214187    1.24575459  1.22903828  1.29582102  0.77289158
#    0.65030629  1.24766423  0.91727786  0.70789842  1.30079969  1.29099126
#    1.17233072  1.11967397  1.27703214  1.27903269  1.16556976  1.1313557
#    0.75815068  1.19558839  1.12524393  2.1185422   0.73479106  1.24332652
#    1.21830964  1.23005126  1.61307729  1.18070071  1.15840525  1.11565464
#    1.12016001  1.23050464  0.82355083  1.21439966  1.24351447  1.18301307
#    0.78107824  1.20771613  0.7329409   0.83691617  1.2346778   1.11725848
#    0.85147527  1.19826685  0.76028548  1.27787148  1.68195699  1.26154726
#    1.2451865   0.80703107  0.7147823   0.86070579  1.18182355  0.74195597
#    1.31626465  1.2596932   0.76905067  1.71851125  1.2531238   0.83510839
#    1.24185768  1.14499472  1.22210261  1.29776594  1.1957671   0.89377753
#    0.74158758  1.24284299  0.74828613  1.24665065  1.24208709]
#  [ 0.72623689  0.78493623  0.80979014  0.72862243  0.85493614  0.77197131
#    0.87488318  0.7835202   0.74001818  0.72624886  0.76167002  1.18631775
#    1.33081919  0.72150014  1.25695804  1.16233389  0.7034557   0.83912313
#    0.79513806  0.72375813  0.82554214  0.74255915  0.74039259  0.77366706
#    1.14095768  0.81191697  0.70773944  1.19730575  1.21781138  0.70770805
#    0.79105232  0.81824218  0.80349258  0.92112971  0.87051193  0.77382279
#    0.78073366  0.85231382  1.24886991  0.78766338  0.73615267  0.79265729
#    1.65616758  0.84204894  1.68318521  1.1602103   0.76541345  0.93147903
#    1.20843986  0.7640675   1.24104025  0.79528197  0.80897824  0.70085435
#    1.19465397  1.18264425  1.2389579   1.59237388  0.83572171  1.23854922
#    0.82386421  0.7797203   1.19729932  0.84896849  0.83695119  1.24076674
#    0.7447092   0.83254333  0.82861834  0.69249505  0.81106042  1.17674345
#    1.21176247  0.68572084  1.22492985  0.77037621  0.7811001 ]]
