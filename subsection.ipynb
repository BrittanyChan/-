# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\yanyuyao\Desktop\chenxi\subsection.csv',encoding= 'gbk')

df.head()
# Out:
#                    券条码    销售额  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  x736001000315363413  68.20         NaN         NaN         NaN         NaN
# 1  x736001000315366021  68.40         NaN         NaN         NaN         NaN
# 2  x736001000316157712  68.60         NaN         NaN         NaN         NaN
# 3  x736001000317223809  68.70         NaN         NaN         NaN         NaN
# 4  x736001000318768114  68.83         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         NaN         NaN         NaN         NaN          NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN          NaN
#
# ...

# %%
df = df[['券条码','销售额']]

# %%
df.head()
# Out:
#                    券条码    销售额
# 0  x736001000315363413  68.20
# 1  x736001000315366021  68.40
# 2  x736001000316157712  68.60
# 3  x736001000317223809  68.70
# 4  x736001000318768114  68.83

# %%
df_below88 = len(df[df['销售额']<88])

# %%
df_below88
# Out:
# 115

# %%
df_below108 = len(df[(88<=df['销售额']) & (df['销售额']<108)])

# %%
df_below108
# Out:
# 35

# %%
df_below128 = len(df[(108<=df['销售额']) & (df['销售额']<128)])

# %%
df_below128
# Out:
# 26

# %%
df_below148 = len(df[(128<=df['销售额']) & (df['销售额']<148)])
df_below148
# Out:
# 23

# %%
df_below168 = len(df[(148<=c) & (df['销售额']<168)])
df_below168
# Out:
# 14

# %%
max(df['销售额'])
# Out:
# 1116.8599999999999

# %%
subsection = []
for i in range(int(round(max(df['销售额'])/20)-3)):
    temp = len(df[((68+i*20)<=df['销售额']) & (df['销售额']<(68+(i+1)*20))])    
    subsection.append(temp)

# %%
salesTitles = []
for i in range(int(round(max(df['销售额'])/20)-3)):
    temp = str(68+i*20)+ '<= 销售额< ' + str(68+(i+1)*20)    
    salesTitles.append(temp)

# %%
df_sales = pd.DataFrame()

# %%
df_sales['销售额'] = salesTitles

# %%
df_sales['数量'] = subsection

# %%
df_sales
# Out:
#                  销售额   数量
# 0       68<= 销售额< 88  115
# 1      88<= 销售额< 108   35
# 2     108<= 销售额< 128   26
# 3     128<= 销售额< 148   23
# 4     148<= 销售额< 168   14
# 5     168<= 销售额< 188   20
# 6     188<= 销售额< 208   16
# 7     208<= 销售额< 228   15
# 8     228<= 销售额< 248    7
# 9     248<= 销售额< 268   14
# 10    268<= 销售额< 288    8
# 11    288<= 销售额< 308    7
# 12    308<= 销售额< 328    9
# 13    328<= 销售额< 348    4
# 14    348<= 销售额< 368    3
# 15    368<= 销售额< 388    6
# 16    388<= 销售额< 408    4
# 17    408<= 销售额< 428    2
# 18    428<= 销售额< 448    3
# 19    448<= 销售额< 468    4
# 20    468<= 销售额< 488    2
# 21    488<= 销售额< 508    2
# 22    508<= 销售额< 528    2
# 23    528<= 销售额< 548    4
# 24    548<= 销售额< 568    3
# 25    568<= 销售额< 588    1
# 26    588<= 销售额< 608    2
# 27    608<= 销售额< 628    2
# 28    628<= 销售额< 648    0
# 29    648<= 销售额< 668    1
# 30    668<= 销售额< 688    3
# 31    688<= 销售额< 708    1
# 32    708<= 销售额< 728    1
# 33    728<= 销售额< 748    0
# ...

# %%
# 可以把它拿出来变成list再进行循环，失败的尝试

# %%
subsection = []
for i in range(round(max(dfList))-1):

# %%
import numpy as np

dfList = df[['销售额']].values

# %%
dfList = [i[0] for i in dfList]

# %%
dfList
# Out:
# [68.200000000000003,
#  68.400000000000006,
#  68.599999999999994,
#  68.700000000000003,
#  68.829999999999998,
#  68.969999999999999,
#  69.019999999999996,
#  69.019999999999996,
#  69.090000000000003,
#  69.120000000000005,
#  69.200000000000003,
#  69.239999999999995,
#  69.299999999999997,
#  69.310000000000002,
#  69.349999999999994,
#  69.450000000000003,
#  69.579999999999998,
#  69.670000000000002,
#  69.700000000000003,
#  69.799999999999997,
#  69.799999999999997,
#  69.840000000000003,
#  69.859999999999999,
#  69.879999999999995,
#  69.900000000000006,
#  70.099999999999994,
#  70.170000000000002,
#  70.180000000000007,
#  70.299999999999997,
#  70.319999999999993,
#  70.340000000000003,
#  70.430000000000007,
#  70.560000000000002,
#  70.560000000000002,
#  70.719999999999999,
#  71.030000000000001,
#  71.200000000000003,
#  71.200000000000003,
#  71.469999999999999,
#  71.579999999999998,
#  71.700000000000003,
#  72.040000000000006,
#  72.069999999999993,
# ...
