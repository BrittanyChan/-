# %%
import pandas as pd

listfile = []
for i in range(1,32):
    file = pd.read_excel('feiniu_data/'+str(i)+'.xls')
    listfile.append(file)

# %%
listfile
# Out:
# [                      子单号                  订单号 订单类型     箱号     发货仓库        站点  \
#  0    20180617HD269A007671  1806143771040651614  取件单  63879   欧尚西红门店   欧尚西红门店站
#  1    20180615HDFCFE007593  1806136324662545043  取件单  63695    欧尚永宁店    欧尚永宁店站
#  2    20180615HDBFC7006149  1806143655870045012  取件单  63698    欧尚建邺店    欧尚建邺店站
#  3    20180614HD6056006118  1806144314245567190  取件单  63601    欧尚高浪店    欧尚高浪店站
#  4    20180614HD42B5007974  1806143056241070134  取件单  63578    欧尚科兴店    欧尚科兴店站
#  5    20180613HD6CE8007954  1806134246021035856  取件单  63534    欧尚武汉店    欧尚武汉店站
#  6    20180613HD6CE8007946  1806134246021035856  取件单  63500    欧尚武汉店    欧尚武汉店站
#  7    20180611HD8528007866  1806106947792270127  取件单  63282    欧尚东邑店    欧尚东邑店站
#  8    20180610HDDDE2007398  1806104217670571680  取件单  63212    欧尚东邑店    欧尚东邑店站
#  9    20180610HDDDE2007393  1806104217670571680  取件单  63172    欧尚东邑店    欧尚东邑店站
#  10   20180607HD30C3007279  1806074073682844315  取件单  62889    欧尚东升店    欧尚东升店站
# ...

# %%
file = pd.concat(listfile)

# %%
len(file)
# Out:
# 30971

# %%
file.to_excel('all.xls')
